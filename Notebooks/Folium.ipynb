# %% [markdown]
# ### Importing folium
#
# In Python, modules are accessed by using the import statement. When you do this, you execute the code of the module, keeping the scopes of the definitions so that your current file(s) can make use of these.

# %% [markdown]
# ### Folium
#
# Folium is a Python module that allows us to create beautiful maps for data visualization.
#
# Folium makes it easy to visualize data that’s been manipulated in Python on an interactive Leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing Vincent/Vega visualizations as markers on the map.

# %%
import folium

# %% [markdown]
# ### Creating a base map
#
# We first create a base map in our region of interest by passing the latitude and longitude. In our case, the region of interest is Kolkata.

# %%
map_1 = folium.Map(location=[22.5726, 88.3639])

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Zooming into the base map
#
# We adjust the zoom by trial and error method to get a better look into our region of interest. The output displays a blank base map.

# %%
map_1 = folium.Map(location=[22.5726, 88.3639],zoom_start=12)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Defining a function for popup markers on the map
#
# We define a function called plotstore to plot store locations on our base map. The function takes three user inputs, the name, latitude and the longitude of the store. We use the Marker method of Folium to create the marker and specify the popup to show the name of the store and the icon to be of red color. Read the documentation to have a better understanding of the available icons and the distinct attributes of the Marker method.
#
# By using the add_child method, we now add this marker to the base map we just created.

# %%
def plotstore(name,lat,longi):
    global folium,map_1

    x=folium.Marker([lat,longi],
              popup=name,
              icon=folium.Icon(color='red'))
    map_1.add_child(x)

# %% [markdown]
# ### Checking with a sample data
#
# To check whether the function works properly or not, we define a random name as 'My Zone' and give coordinates for it. The output shows that the red marker is distinctly visible on the map.

# %%
plotstore('My Zone',22.5578457,88.3545395)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Plotting store locations for the data from the zomato scrape
#
# #### Reading data from the excel file of the zomato scrap
#
# With our basic understanding of Pandas Dataframe and folium ready, we try to plot the store locations on the base map. We first read the excel file that contains the data of the zomato scrap using the read_excel method of the pandas DataFrame. We view the df to check whether the excel file has been uploaded properly or not and use the len(df) syntax to check the number of restaurants in the excel file

# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\User\Desktop\Restaurant_Data.xlsx")

# %%
df
# Out:
#        latitude  longitude                                    name  \
# 0     22.568942  88.433182                         Barbeque Nation
# 1     22.513738  88.362721                               What's Up
# 2     22.552505  88.352699                               Peter Cat
# 3     22.518565  88.350252                               Oudh 1590
# 4     22.514874  88.393295                               Hoppipola
# 5     22.514874  88.393295                                   Ozora
# 6     22.527914  88.367988                      6 Ballygunge Place
# 7     22.547959  88.399283  JW Kitchen - JW Marriott Hotel Kolkata
# 8     22.526294  88.364614                             Spice Kraft
# 9     22.552896  88.352538                                   BarBQ
# 10    22.623304  88.450278                       Traffic Gastropub
# 11    22.542004  88.363611                                 Arsalan
# 12    22.542285  88.351764                               Scrapyard
# 13    22.541925  88.385800                                The GRID
# 14    22.538275  88.365326                     Chili's Grill & Bar
# 15    22.568942  88.433182                         Barbeque Nation
# 16    22.513738  88.362721                               What's Up
# 17    22.552505  88.352699                               Peter Cat
# 18    22.518565  88.350252                               Oudh 1590
# 19    22.514874  88.393295                               Hoppipola
# 20    22.514874  88.393295                                   Ozora
# 21    22.527914  88.367988                      6 Ballygunge Place
# 22    22.547959  88.399283  JW Kitchen - JW Marriott Hotel Kolkata
# 23    22.526294  88.364614                             Spice Kraft
# 24    22.552896  88.352538                                   BarBQ
# 25    22.623304  88.450278                       Traffic Gastropub
# 26    22.542004  88.363611                                 Arsalan
# 27    22.542285  88.351764                               Scrapyard
# 28    22.541925  88.385800                                The GRID
# 29    22.538275  88.365326                     Chili's Grill & Bar
# ...         ...        ...                                     ...
# 3914  22.441823  88.395457                         Orion Fast Food
# 3915  22.622960  88.450713                             Zion Lounge
# 3916  22.617077  88.347435                                  Fusion
# 3917  22.760951  88.366695                           Daawat-e-ishq
# 3918  22.512846  88.392102                             Sasta Thali
# 3919  22.569427  88.433431                          Buddhaa Lounge
# 3920  22.591966  88.317667             The Park Terrace Restaurant
# 3921  22.653096  88.377393                              Wah Punjab
# 3922  22.501156  88.340499                              Ranna Bati
# 3923  22.601198  88.373367                          Tongue Twister
# 3924  22.615903  88.420084                           Food Junction
# 3925  22.560605  88.351582                      Ruchika Restaurant
# 3926  22.516278  88.348978                        Tropical Chinese
# 3927  22.587353  88.404172                       Fikar Not Foodies
# 3928  22.590580  88.340398                                 Ralli's
# 3929  22.615525  88.412497                           Dumpling Momo
# 3930  22.617409  88.425144           Annapurna Pure Veg Restaurant
# 3931  22.698107  88.387851                           Kebab Kolkata
# 3932  22.698107  88.387851                         Healing Kitchen
# 3933  22.590562  88.340526                             Super South
# 3934  22.563241  88.323684                               7th Spice
# 3935  22.365372  88.429398                                  Bedwin
# 3936  22.515748  88.350584                       Flavours of South
# 3937  22.583027  88.238607                    Signature restaurant
# 3938  22.583027  88.238607                        Big Fat Shawarma
# 3939  22.537860  88.367315              QFC- Quality Fried Chicken
# 3940  22.517008  88.365819                         New Karco Hotel
# 3941  22.478468  88.281603                          Asit Snaks Bar
# 3942  22.590485  88.340472                           Beans & Roots
# 3943  22.504753  88.367011                           Roasted Beans
#
#                                                 Address  \
# 0      K1, RDB Boulevard, Block EP & GP, Sector 5, S...
# 1                        122A, Southern Avenue, Kolkata
# 2           18A, Park Street, Park Street Area, Kolkata
# 3                            23/B, Desapriya Park(West)
# 4      Acropolis Mall (4th Floor),1858, Rajdanga Mai...
# 5      Acropolis Mall, 1858, Rajdanga Main Road, Kas...
# 6              6, Ballygunge Place, Ballygunge, Kolkata
# 7      JW Marriott Hotel Kolkata, 4A, J.B.S Haldane ...
# 8      54/1/2A, Hazra Road, Ballygunge Phari, Near H...
# 9                   43-47-55, Park Street Area, Kolkata
# 10                                                  NaN
# 11     28, Circus Avenue, Near A.J.C. Bose Road Flyo...
# 12     10th Floor, 12-A, Usha Kiran Building, Camac ...
# 13     Haute Street Corporate Park, 86A Topsia Road ...
# 14     4th Floor, Quest Mall, 33, Syed Ali Amir Aven...
# 15     K1, RDB Boulevard, Block EP & GP, Sector 5, S...
# 16                       122A, Southern Avenue, Kolkata
# 17          18A, Park Street, Park Street Area, Kolkata
# 18                           23/B, Desapriya Park(West)
# 19     Acropolis Mall (4th Floor),1858, Rajdanga Mai...
# 20     Acropolis Mall, 1858, Rajdanga Main Road, Kas...
# 21             6, Ballygunge Place, Ballygunge, Kolkata
# 22     JW Marriott Hotel Kolkata, 4A, J.B.S Haldane ...
# 23     54/1/2A, Hazra Road, Ballygunge Phari, Near H...
# 24                  43-47-55, Park Street Area, Kolkata
# 25                                                  NaN
# 26     28, Circus Avenue, Near A.J.C. Bose Road Flyo...
# 27     10th Floor, 12-A, Usha Kiran Building, Camac ...
# 28     Haute Street Corporate Park, 86A Topsia Road ...
# 29     4th Floor, Quest Mall, 33, Syed Ali Amir Aven...
# ...                                                 ...
# 3914              388, N.S.C. Bose Road, Garia, Kolkata
# 3915                        Ground Floor, City Centre 2
# 3916   151/1, Bidhan Sarani, Near Star Theatre, Hati...
# 3917   48(36), BT Road, Near BN bose hospital, Kolka...
# 3918                                                NaN
# 3919   1st Floor, Infinity Benchmark, Near RDB Cinem...
# 3920                                                NaN
# 3921   150, B.T. Road, Near Dunlop Bridge, Baranagar...
# 3922   35A B.L.Saha Road, Mahabirtala, Tollygunge, K...
# 3923          114B, Bidhan Sarani, Shyam Bazar, Kolkata
# 3924                                                NaN
# 3925         4, Humayun Place, New Market Area, Kolkata
# 3926   4th Floor, Yum Street, Lake Mall, 104, Rash B...
# 3927                                                NaN
# 3928           56, Ballygunge Gardens, Golpark, Kolkata
# 3929   4th Floor, Diamond Plaza Mall, 68 Jessore Roa...
# 3930                                                NaN
# 3931                                                NaN
# 3932                                                NaN
# 3933                                                NaN
# 3934                                                NaN
# 3935          46/2/1A, Gariahat Road, Gariahat, Kolkata
# 3936                                                NaN
# 3937                                                NaN
# 3938   3A, Humayun Palace, Lindsay Street, New Marke...
# 3939                                                NaN
# 3940                                                NaN
# 3941                                                NaN
# 3942                                                NaN
# 3943                                                NaN
#
#                                               Area  Cost for two  \
# 0                          RDB Boulevard, Sector 5        1400.0
# 1                                  Southern Avenue        1000.0
# 2                                 Park Street Area        1200.0
# 3                                   Desapriya Park        1200.0
# 4                            Acropolis Mall, Kasba        1500.0
# 5                            Acropolis Mall, Kasba        1700.0
# 6                                       Ballygunge        1000.0
# 7     JW Marriott Hotel Kolkata, Science City Area        2000.0
# 8                                       Ballygunge        1200.0
# 9                                 Park Street Area         900.0
# 10                                             NaN           NaN
# 11                                Park Circus Area         700.0
# 12                               Camac Street Area        1100.0
# 13                                          Topsia        1800.0
# 14                          Quest Mall, Ballygunge        1700.0
# 15                         RDB Boulevard, Sector 5        1400.0
# 16                                 Southern Avenue        1000.0
# 17                                Park Street Area        1200.0
# 18                                  Desapriya Park        1200.0
# 19                           Acropolis Mall, Kasba        1500.0
# 20                           Acropolis Mall, Kasba        1700.0
# 21                                      Ballygunge        1000.0
# 22    JW Marriott Hotel Kolkata, Science City Area        2000.0
# 23                                      Ballygunge        1200.0
# 24                                Park Street Area         900.0
# 25                                             NaN           NaN
# 26                                Park Circus Area         700.0
# 27                               Camac Street Area        1100.0
# 28                                          Topsia        1800.0
# 29                          Quest Mall, Ballygunge        1700.0
# ...                                            ...           ...
# 3914                                         Garia         100.0
# 3915         City Centre 2 Mall, Rajarhat New Town         800.0
# 3916                                     Hatibagan         600.0
# 3917                                   Barrackpore         500.0
# 3918                                           NaN           NaN
# 3919                           Sector 5, Salt Lake         700.0
# 3920                                           NaN           NaN
# 3921                                     Baranagar         400.0
# 3922                                    Tollygunge         500.0
# 3923                                   Shyam Bazar         500.0
# 3924                                           NaN           NaN
# 3925                               New Market Area         300.0
# 3926                 Lake Mall, Rash Behari Avenue         500.0
# 3927                                           NaN           NaN
# 3928                                       Golpark         250.0
# 3929              Diamond Plaza Mall, Jessore Road         300.0
# 3930                                           NaN           NaN
# 3931                                           NaN           NaN
# 3932                                           NaN           NaN
# 3933                                           NaN           NaN
# 3934                                           NaN           NaN
# 3935                                      Gariahat         500.0
# 3936                                           NaN           NaN
# 3937                                           NaN           NaN
# 3938                               New Market Area         600.0
# 3939                                           NaN           NaN
# 3940                                           NaN           NaN
# 3941                                           NaN           NaN
# 3942                                           NaN           NaN
# 3943                                           NaN           NaN
#
#                                                 Cuisine  \
# 0      North Indian, Chinese, Charcoal Grill, Kebab,...
# 1                  Chinese, Continental, Italian, Kebab
# 2                             Continental, North Indian
# 3                                       Mughlai, Awadhi
# 4             Italian, Mexican, American, Mediterranean
# 5                                 Chinese, North Indian
# 6                                               Bengali
# 7      North Indian, European, Mediterranean, Thai, ...
# 8                    Continental, Asian, Middle Eastern
# 9                                 Chinese, North Indian
# 10                                                  NaN
# 11                         North Indian, Mughlai, Rolls
# 12                   North Indian, Chinese, Continental
# 13                  Continental, Burger, Italian, Pizza
# 14                   American, Mexican, Italian, Burger
# 15     North Indian, Chinese, Charcoal Grill, Kebab,...
# 16                 Chinese, Continental, Italian, Kebab
# 17                            Continental, North Indian
# 18                                      Mughlai, Awadhi
# 19            Italian, Mexican, American, Mediterranean
# 20                                Chinese, North Indian
# 21                                              Bengali
# 22     North Indian, European, Mediterranean, Thai, ...
# 23                   Continental, Asian, Middle Eastern
# 24                                Chinese, North Indian
# 25                                                  NaN
# 26                         North Indian, Mughlai, Rolls
# 27                   North Indian, Chinese, Continental
# 28                  Continental, Burger, Italian, Pizza
# 29                   American, Mexican, Italian, Burger
# ...                                                 ...
# 3914                          Street Food, North Indian
# 3915                                 Fast Food, Chinese
# 3916                              North Indian, Chinese
# 3917          North Indian, South Indian, Chinese, Thai
# 3918                                                NaN
# 3919                                          Fast Food
# 3920                                                NaN
# 3921                 North Indian, Chinese, Street Food
# 3922                                            Bengali
# 3923                     Chinese, North Indian, Mughlai
# 3924                                                NaN
# 3925                          North Indian, Street Food
# 3926                                            Chinese
# 3927                                                NaN
# 3928                  South Indian, Street Food, Juices
# 3929                         Chinese, Nepalese, Tibetan
# 3930                                                NaN
# 3931                                                NaN
# 3932                                                NaN
# 3933                                                NaN
# 3934                                                NaN
# 3935                       Chinese, North Indian, Rolls
# 3936                                                NaN
# 3937                                                NaN
# 3938                                           Lebanese
# 3939                                                NaN
# 3940                                                NaN
# 3941                                                NaN
# 3942                                                NaN
# 3943                                                NaN
#
#                                                   Hours  Ratings  \
# 0                                     12 Noon to 2:4...      4.8
# 1                                     12 Noon to 12 ...      4.1
# 2                                     11 AM to 11:20...      4.2
# 3                                     12 Noon to 3:3...      4.3
# 4                                     12:30 PM to 11...      4.1
# 5                                     4 PM to 12 Mid...      3.8
# 6                                     12:30 PM to 3:...      4.5
# 7                                     24 Hours (Mon-...      4.5
# 8                                     12 Noon to 3 P...      4.8
# 9                                     12 Noon to 11:...      4.3
# 10                                                  NaN      NaN
# 11                                    11 AM to 12 Mi...      4.2
# 12                                    1 PM to 12 Mid...      3.6
# 13                                    12 Noon to 12 ...      4.3
# 14                                    12 Noon to 11:...      4.9
# 15                                    12 Noon to 2:4...      4.8
# 16                                    12 Noon to 12 ...      4.1
# 17                                    11 AM to 11:20...      4.2
# 18                                    12 Noon to 3:3...      4.3
# 19                                    12:30 PM to 11...      4.1
# 20                                    4 PM to 12 Mid...      3.8
# 21                                    12:30 PM to 3:...      4.5
# 22                                    24 Hours (Mon-...      4.5
# 23                                    12 Noon to 3 P...      4.8
# 24                                    12 Noon to 11:...      4.3
# 25                                                  NaN      NaN
# 26                                    11 AM to 12 Mi...      4.2
# 27                                    1 PM to 12 Mid...      3.6
# 28                                    12 Noon to 12 ...      4.3
# 29                                    12 Noon to 11:...      4.9
# ...                                                 ...      ...
# 3914                                  8 AM to 10 PM ...      2.6
# 3915                                  12 Noon to 10 ...      2.2
# 3916                                  12 Noon to 10:...      2.1
# 3917                                  11:30 AM to 11...      2.8
# 3918                                                NaN      NaN
# 3919                                  12 Noon to 11 ...      2.5
# 3920                                                NaN      NaN
# 3921                                  11 AM to 11 PM...      3.0
# 3922                                  12 Noon to 10:...      3.3
# 3923                                  12 Noon to 10 ...      2.0
# 3924                                                NaN      NaN
# 3925                                  12 Noon to 9 P...      2.6
# 3926                                  11 AM to 9 PM ...      3.3
# 3927                                                NaN      NaN
# 3928                                  11 AM to 10 PM...      3.5
# 3929                                  11:30 AM to 9:...      3.1
# 3930                                                NaN      NaN
# 3931                                                NaN      NaN
# 3932                                                NaN      NaN
# 3933                                                NaN      NaN
# 3934                                                NaN      NaN
# 3935                                  10:30 AM to 11...      3.2
# 3936                                                NaN      NaN
# 3937                                                NaN      NaN
# 3938                                  11 AM to 10 PM...      3.2
# 3939                                                NaN      NaN
# 3940                                                NaN      NaN
# 3941                                                NaN      NaN
# 3942                                                NaN      NaN
# 3943                                                NaN      NaN
#
#                             Type       Votes  \
# 0                  Casual Dining  6424 votes
# 1           Casual Dining,Lounge  1730 votes
# 2                  Casual Dining  8396 votes
# 3                  Casual Dining  4065 votes
# 4              Bar,Casual Dining  1721 votes
# 5                     Bar,Lounge   448 votes
# 6                  Casual Dining  2067 votes
# 7                  Casual Dining  1040 votes
# 8                  Casual Dining  2231 votes
# 9              Casual Dining,Bar  5789 votes
# 10                           NaN         NaN
# 11                 Casual Dining  4227 votes
# 12          Lounge,Casual Dining   227 votes
# 13    Microbrewery,Casual Dining   670 votes
# 14             Casual Dining,Bar  4352 votes
# 15                 Casual Dining  6424 votes
# 16          Casual Dining,Lounge  1730 votes
# 17                 Casual Dining  8396 votes
# 18                 Casual Dining  4065 votes
# 19             Bar,Casual Dining  1721 votes
# 20                    Bar,Lounge   448 votes
# 21                 Casual Dining  2067 votes
# 22                 Casual Dining  1040 votes
# 23                 Casual Dining  2231 votes
# 24             Casual Dining,Bar  5789 votes
# 25                           NaN         NaN
# 26                 Casual Dining  4227 votes
# 27          Lounge,Casual Dining   227 votes
# 28    Microbrewery,Casual Dining   670 votes
# 29             Casual Dining,Bar  4352 votes
# ...                          ...         ...
# 3914                 Quick Bites    13 votes
# 3915               Casual Dining    49 votes
# 3916               Casual Dining   440 votes
# 3917                 Quick Bites    20 votes
# 3918                         NaN         NaN
# 3919               Casual Dining    34 votes
# 3920                         NaN         NaN
# 3921               Casual Dining    64 votes
# 3922                 Quick Bites    30 votes
# 3923                 Quick Bites   197 votes
# 3924                         NaN         NaN
# 3925               Casual Dining    65 votes
# 3926                  Food Court    74 votes
# 3927                         NaN         NaN
# 3928               Casual Dining   144 votes
# 3929                  Food Court   131 votes
# 3930                         NaN         NaN
# 3931                         NaN         NaN
# 3932                         NaN         NaN
# 3933                         NaN         NaN
# 3934                         NaN         NaN
# 3935               Casual Dining   329 votes
# 3936                         NaN         NaN
# 3937                         NaN         NaN
# 3938                 Quick Bites    21 votes
# 3939                         NaN         NaN
# 3940                         NaN         NaN
# 3941                         NaN         NaN
# 3942                         NaN         NaN
# 3943                         NaN         NaN
#
#                                            Food-choices
# 0     ChickenDumBiryani,VegetableBiryani,MalaiKofta,...
# 1     ChickenTikka,Mocktails,KiwiMojito,Bruschettas,...
# 2     CheloKebab,PrawnCurry,Screwdriver,MangoSouffle...
# 3     RaanBiryani,GalautiKebab,Kheer,DalMakhani,Chic...
# 4     Risotto,PorkPlatter,Brownie,PassionMartini,Lon...
# 5                   Mocktails,CrispyChicken,DaabChingri
# 6     DaabChingri,FriedFish,Luchi,DimerDevil,BhapaDo...
# 7     PaneerTikka,MuttonBiryani,ChocolateMousse,Nood...
# 8     ShephardsPie,Mocktails,DajajChermoula,Mousse,S...
# 9     Noodles,ChickenButterMasala,ChickenHakkaChowme...
# 10                                        FriendlyStaff
# 11    Firni,MuttonKosha,ChickenChatpata,MuttonBiryan...
# 12         PaneerTikka,Mocktails,VirginMojito,Chocolava
# 13    ThinCrustPizza,Mocktails,CraftBeer,Stout,Brewe...
# 14    TomatoSoup,Sangria,SantaFeSalad,Mocktails,Faji...
# 15    ChickenDumBiryani,VegetableBiryani,MalaiKofta,...
# 16    ChickenTikka,Mocktails,KiwiMojito,Bruschettas,...
# 17    CheloKebab,PrawnCurry,Screwdriver,MangoSouffle...
# 18    RaanBiryani,GalautiKebab,Kheer,DalMakhani,Chic...
# 19    Risotto,PorkPlatter,Brownie,PassionMartini,Lon...
# 20                  Mocktails,CrispyChicken,DaabChingri
# 21    DaabChingri,FriedFish,Luchi,DimerDevil,BhapaDo...
# 22    PaneerTikka,MuttonBiryani,ChocolateMousse,Nood...
# 23    ShephardsPie,Mocktails,DajajChermoula,Mousse,S...
# 24    Noodles,ChickenButterMasala,ChickenHakkaChowme...
# 25                                        FriendlyStaff
# 26    Firni,MuttonKosha,ChickenChatpata,MuttonBiryan...
# 27         PaneerTikka,Mocktails,VirginMojito,Chocolava
# 28    ThinCrustPizza,Mocktails,CraftBeer,Stout,Brewe...
# 29    TomatoSoup,Sangria,SantaFeSalad,Mocktails,Faji...
# ...                                                 ...
# 3914                                                NaN
# 3915                                           Decor,Dj
# 3916  CrispyBabycorn,DragonChicken,TikkaKebab,Chilli...
# 3917                                                NaN
# 3918                                                NaN
# 3919                               CrispyChilliBabycorn
# 3920                                         DalMakhani
# 3921  Chaat,Lassi,DalMakhani,PavBhaji,AlooParatha,Cr...
# 3922                                                NaN
# 3923                     TandooriChicken,ChilliBabycorn
# 3924     ChickenBharta,Noodles,RumaliRoti,GarlicChicken
# 3925                              ChilliChicken,Noodles
# 3926  ManchurianSizzler,HakkaNoodles,ChickenManchuri...
# 3927                     Momos,Manchurian,ChilliChicken
# 3928  Kulfi,Lassi,PapdiChaat,DahiVada,CholeBhature,F...
# 3929  ClearSoup,PanFriedMomos,ChickenMomo,ChickenThu...
# 3930                                                NaN
# 3931                                                NaN
# 3932                                                NaN
# 3933                                                NaN
# 3934                                                NaN
# 3935  ChikenRoll,ReshmiKebab,EggRoll,Chaap,TandooriC...
# 3936                                                NaN
# 3937                                                NaN
# 3938                                                NaN
# 3939                                                NaN
# 3940                                                NaN
# 3941                                                NaN
# 3942                                                NaN
# 3943                                                NaN
#
# [3944 rows x 12 columns]

# %%
len(df)
# Out:
# 3944

# %% [markdown]
# ### Plotting the restaurants on the base map
#
# We now run a loop which will take the names under the index of name in the excel file and select it using the iloc method of dataframe. The name will be stored in a variable name1. Now, calling the plotstore function that we created before we will call the plotstore function that we defined before to plot the restaurant markers on the base map.

# %%
for i in range(len(df)):
    try:
        name1=str(df.iloc[i]['name'])
    except:
        name1=''
    name1=name1.replace("'","")
    plotstore(name1,float(df.iloc[i]['latitude']),float(df.iloc[i]['longitude']))
    
map_1

# %% [markdown]
# #### We now zoom into the map for better visualization.

# %%
map_2 = folium.Map(location=[22.5726, 88.3639],zoom_start=12)

# %% [markdown]
# ### Creating a Feature Group
#
# Now, instead off adding individual markers one by one to the map, we will create a feature group using the FeatureGroup syntax of the folium module. This will enable us to add the entire feature group as a layer onto the base map.
#
# The add_child method of the map will enable us to add the feature group to the base map.
#
# ### Layer Control
#
# We can use the LayerControl() feature of the folium module to shift between layers that will appear as a stack icon on the top right of the base map.

# %%
f1=folium.FeatureGroup(name='Restaurants')

def plotstore(name,lat,longi):
    global folium,map_2,f1

    x=folium.Marker([lat,longi],
              popup=name,
              icon=folium.Icon(color='red'))
    f1.add_child(x)
map_2.add_child(f1)

folium.LayerControl().add_to(map_2)

# %% [markdown]
# #### We now plot by the previous method without using feature to see the difference.

# %%
for i in range(len(df)):
    try:
        name1=str(df.iloc[i]['name'])
    except:
        name1=''
    name1=name1.replace("'","")
    plotstore(name1,float(df.iloc[i]['latitude']),float(df.iloc[i]['longitude']))
    
map_2

# %% [markdown]
# #### Plot to see difference.

# %%
map_3 = folium.Map(location=[22.5726, 88.3639],zoom_start=12)

# %% [markdown]
# ### Saving every type of restaurant in a list and making a feature out of it
#
# We define an empty list 'typ' and for every element in the 'Type' column of the restaurant data, we add it to the empty list until finally we have a set of types of restaurant. We can now add this to an empty dictionary, fold with key value as the 'type' of restaurant e.g Cafe, Bar, Continental and so on and the value will be a folium Feature group of the same name.

# %%
typ=[]
for n in df['Type']:
    try:
        t=[x for x in n.split(',')]
        typ+=t
    except:
        pass
typ=list(set(typ))
fold={}
for i in typ:
    fold[i]=folium.FeatureGroup(name=i)

# %%
fold

# %% [markdown]
# ### Defining a function to add the different restaurants on the map
#
# We then define a function plottyp that takes name, latitude, longitude as the output and adds it to the dictionary that we just created for different features as a child element. So basically we have a dictionary with c as the key and the marker of the restaurant as value.

# %%
def plottyp(name,lat,longi,c):
    global folium,map_3,fold

    x=folium.Marker([lat,longi],
              popup=name,
              icon=folium.Icon(color='green'))
    fold[c].add_child(x)

# %% [markdown]
# ### Inserting the type of restaurants and the restaurants layer to the map
#
# So now basically since we have created separate dictionaries using the restaurant name and type of restaurants and made features out of them, we can basically add them to the base map and include layer control.

# %%
for i in range(len(df)):
    try:
        name1=str(df.iloc[i]['name'])
    except:
        name1=''
    name1=name1.replace("'","")
    try:
        tc=[x for x in df.iloc[i]['Type'].split(',')]
    except:
        tc=[]
    for a in tc:
        plottyp(name1,float(df.iloc[i]['latitude']),float(df.iloc[i]['longitude']),a)
    
    

for b in fold:
    map_3.add_child(fold[b])
    
folium.LayerControl().add_to(map_3)

# %%
map_3

# %% [markdown]
# ### Inlcuding the shape files for Assembly constituencies in West Bengal
#
# FIrst, we need to import the module of json to allow us to process json files in python. We import folium to plot the json data onto a map.

# %%
import json

# %%
import folium

# %% [markdown]
# #### We first load the json data into a variable d and print it

# %%
with open('WB_AC.json') as json_data:
    d = json.load(json_data)
d

# %% [markdown]
# #### We create a feature group for the assembly contituencies and create a base map using

# %%
f3=folium.FeatureGroup(name='AC')

# %%
map_4 = folium.Map(location=[22.5726, 88.3639])

# %% [markdown]
# #### Creating polygons from the JSON data
#
# We use the GeoJson method of the folium library to create polygons whose coordinates are the coordinates of the assembly constituencies which we add as a child element to the folium map.

# %%
def plotac(name,i):
    
    
    
    global folium,map_1
    style_function = lambda x: {'fillColor': '#CCF9F8'}
    gj = folium.GeoJson(
            data={
                    'type': 'Polygon',
                    'coordinates': i
                    } , style_function=style_function
            )
    gj.add_child(folium.Popup(name))
    f3.add_child(gj)

# %% [markdown]
# #### Displaying the map to see whether the child elements have been added properly or not

# %%
map_4.add_child(f3)

# %%
d

# %%
for j in d['features']:
   plotac(j['properties']['AC_NAME'],j['geometry']['coordinates'])

# %%
map_4

# %% [markdown]
# #### From the shapely module we import the Polygon and Point methods to convert our geojson data to visualizable areas as polygons

# %%
from shapely.geometry import Polygon, Point

# %% [markdown]
# ##### We declare an empty list Polygons which will store all our converted geojson data to polygons

# %%
polygons=[]

# %% [markdown]
# ##### We run an iterative loop to save the polygons into the empty list

# %%
for x in d['features']:
    poly_points = x['geometry']['coordinates'][0]
    poly_points = [tuple(p) for p in poly_points]
    polygons+=[(Polygon(poly_points),x['properties']['id'])]

# %%
polygons

# %%
poly_points

# %% [markdown]
# ##### We create an empty list which will have the polygon as the key and the Cost for two from the Restaurants data as the value

# %%
cost={}
for i in range(len(df)):
    point = Point([df.iloc[i]['longitude'], df.iloc[i]['latitude']])
    for poly in polygons:
        if poly[0].contains(point):
            key=str(poly[1])
            if key in cost.keys():
                try:
                    cost[key]+=[int(df.iloc[i]['Cost for two'])]
                except:
                    pass
            else:
                try:
                    cost[key]=[int(df.iloc[i]['Cost for two'])]
                except:
                    pass

# %%
cost

# %%
len(cost)

# %%
cost.keys()

# %% [markdown]
# ##### We define an empty list and check whether the cost of two are already in the keys that we got from the zomato data

# %%
l1=[]
l2=[int(x) for x in cost.keys()]
for i in d['features']:
    if i['properties']['id'] in l2:
        l1+=[i]
        
len(l1)

# %%
d1={'type':'','features':l1}

len(d1['features'])

# %%
map_5 = folium.Map(location=[22.5726, 88.3639])

# %%
for j in d1['features']:
   plotac(j['properties']['AC_NAME'],j['geometry']['coordinates'])

# %%
map_5.add_child(f3)

# %%
dnew=pd.DataFrame(0,index=range(36),columns=['Id','Average-Cost'],dtype='object')

# %% [markdown]
# #### By running an iterative loop we average out the cost over the list of all the keys

# %%
index=0
for j in cost:
    avg=0
    for i in cost[j]:
        avg+=i
    avg=avg/len(cost[j])
    dnew.iloc[index]=int(j)
    dnew.iloc[index]['Average-Cost']=avg
    index+=1

# %%
dnew

# %% [markdown]
# #### FInally, we add it a choropleth layer to the map and display it as our output.

# %%
map_5.choropleth(geo_data=d,data=dnew,columns=['Id','Average-Cost'],
                 key_on='feature.properties.id',fill_color='OrRd',name='Average Cost',
                 fill_opacity=0.7, line_opacity=0.2,legend_name='Average Cost')

# %%
map_5
